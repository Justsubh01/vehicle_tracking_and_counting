# %% [markdown]
# # Download data
#
# I am using Data which i uploaded on kaggle, it is preprocessed,and formatted according yolov5 documentation.you can download it [here](https://www.kaggle.com/billiemage/vehicle-detection).

# %%
# clone yolov5 for object detector training
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 9829, done.
# remote: Total 9829 (delta 0), reused 0 (delta 0), pack-reused 9829
# Receiving objects: 100% (9829/9829), 10.05 MiB | 1.79 MiB/s, done.
# Resolving deltas: 100% (6841/6841), done.

# %%
# mv tracker and track.py into yolov5 directory
# !mv tracker yolov5/
# !mv track.py yolov5/

# %%
# !tree
# Out:
# .
# ├── best.pt
# ├── last.pt
# ├── the_project
# │   ├── vehicle_classification
# │   │   ├── images
# │   │   │   ├── train
# │   │   │   │   ├── 00000002.jpg
# │   │   │   │   ├── 00000003.jpg
# │   │   │   │   ├── 00000004.jpg
# │   │   │   │   ├── 00000006.jpg
# │   │   │   │   ├── 00000008.jpg
# │   │   │   │   ├── 00000009.jpg
# │   │   │   │   ├── 00000019.jpg
# │   │   │   │   ├── 00000020.jpg
# │   │   │   │   ├── 00000023.jpg
# │   │   │   │   ├── 00000027.jpg
# │   │   │   │   ├── 00000028.jpg
# │   │   │   │   ├── 00000030.jpg
# │   │   │   │   ├── 00000031.jpg
# │   │   │   │   ├── 00000032.jpg
# │   │   │   │   ├── 00000033.jpg
# │   │   │   │   ├── 00000042.jpg
# │   │   │   │   ├── 00000044.jpg
# │   │   │   │   ├── 00000045.jpg
# │   │   │   │   ├── 00000047.jpg
# │   │   │   │   ├── 00000048.jpg
# │   │   │   │   ├── 00000052.jpg
# │   │   │   │   ├── 00000057.jpg
# │   │   │   │   ├── 00000059.jpg
# │   │   │   │   ├── 00000061.jpg
# ...

# %%
# install requirements
# !pip install -r yolov5/requirements.txt
# Out:
# ...
#   Using cached matplotlib-3.4.3-cp38-cp38-manylinux1_x86_64.whl (10.3 MB)
# ...
#   Using cached numpy-1.21.2-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.8 MB)
# ...
#   Using cached opencv_python-4.5.3.56-cp38-cp38-manylinux2014_x86_64.whl (49.9 MB)
# ...
#      |████████████████████████████████| 3.1 MB 25 kB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 701 kB 30 kB/s  eta 0:00:01
# ...
#   Using cached requests-2.26.0-py2.py3-none-any.whl (62 kB)
# ...
#   Using cached scipy-1.7.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (28.4 MB)
# ...
#      |████████████████████████████████| 831.4 MB 3.5 kB/s eta 0:00:013     |██████████████▋                 | 379.1 MB 1.4 MB/s eta 0:05:21     |████████████████████▋           | 536.1 MB 4.3 MB/s eta 0:01:08     |███████████████████████         | 595.3 MB 5.3 MB/s eta 0:00:45
# ...
#      |████████████████████████████████| 22.1 MB 11 kB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 76 kB 21 kB/s  eta 0:00:01
# ...

# %% [markdown]
# # training

# %%
# training
# !python3 ./yolov5/train.py --data ./the_project/vehicle_classification.yaml --cfg ./yolov5/models/yolov5m.yaml --weights yolov5m.pt --batch-size 16 --epochs 10
# Out:
# train: weights=yolov5m.pt, cfg=./yolov5/models/yolov5m.yaml, data=./the_project/vehicle_classification.yaml, hyp=yolov5/data/hyps/hyp.scratch.yaml, epochs=10, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 v6.0-16-g6d9b99f torch 1.9.1+cu102 CPU
#
# ...

# %% [markdown]
# # testing
#
# you can find your best traing weights at **yolov5/runs/train/exp/weights/** Or you can use my weights which is available with this repository.

# %%
# testing 
# !python3 yolov5/track.py --source "test-videos.mp4" --weights best.pt --conf 0.60

# %%
# !ffmpeg -i yolov5/output_03.avi output.mp4
